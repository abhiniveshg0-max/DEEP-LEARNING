# %% [markdown]
# <a href="https://colab.research.google.com/github/abhiniveshg0-max/DEEP-LEARNING/blob/main/experiment_4_d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

GITHUB_USERNAME = "your-username"
GITHUB_TOKEN = "your-personal-access-token"
REPO_NAME = "transfer-learning-lab"
NOTEBOOK_PATH = "/content/drive/MyDrive/Colab Notebooks/EX_4_Transfer_Learning.ipynb"

# !git config --global user.email "you@example.com"
# !git config --global user.name "$GITHUB_USERNAME"

# !git clone https://$GITHUB_TOKEN@github.com/$GITHUB_USERNAME/$REPO_NAME.git

import shutil
shutil.copy(NOTEBOOK_PATH, f"{REPO_NAME}/EX_4_Transfer_Learning.ipynb")

# %cd {REPO_NAME}
# !git add .
# !git commit -m "Add transfer learning lab notebook"
# !git push
# %cd ..

print("Notebook pushed to GitHub successfully.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Cloning into 'github.com'...
# fatal: could not read Username for 'https://github.com': No such device or address
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1402/826058214.py in <cell line: 0>()
#      13
#      14 import shutil
# ---> 15 shutil.copy(NOTEBOOK_PATH, f"{REPO_NAME}/EX_4_Transfer_Learning.ipynb")
#      16
#      17 get_ipython().run_line_magic('cd', '{REPO_NAME}')
#
# /usr/lib/python3.12/shutil.py in copy(src, dst, follow_symlinks)
#     433     if os.path.isdir(dst):
#     434         dst = os.path.join(dst, os.path.basename(src))
# --> 435     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     436     copymode(src, dst, follow_symlinks=follow_symlinks)
#     437     return dst
#
# ...

# %% [markdown]
# After verifying the notebook path, please make sure to update `GITHUB_USERNAME` and `GITHUB_TOKEN` with your actual GitHub credentials in the previous cell (`HZqtRpuv1C-V`).

# %%
import os

# Assuming the notebook is meant to be in '/content/drive/MyDrive/Colab Notebooks/'
# Let's list the contents of that directory to verify.
print('Listing contents of /content/drive/MyDrive/Colab Notebooks/:')
try:
    for item in os.listdir('/content/drive/MyDrive/Colab Notebooks/'):
        print(item)
except FileNotFoundError:
    print('The directory /content/drive/MyDrive/Colab Notebooks/ does not exist. Please check your Google Drive structure.')
# Out:
# Listing contents of /content/drive/MyDrive/Colab Notebooks/:
# Team_6_Report (1).docx
# Untitled0.ipynb
# data_science_assignment (1).ipynb
# data_science_assignment .ipynb
# EX 4 (2).ipynb
# Untitled1.ipynb
# Untitled2.ipynb
# scenario1_user_based_cf.ipynb
# scenario1.ipynb
# scenario1_user_based_cf (3) (1).ipynb
# Untitled3.ipynb
# EX7_Clustering_KMeans_GMM_24BAD002 (2).ipynb
# EX_8_Apriori_and_PCA (4).ipynb
# Untitled4.ipynb
# EX_8_Apriori_and_PCA (3).ipynb
# EX_10_Recommendation_Systems_SVD_NMF (2).ipynb
# EX_8_Apriori_and_PCA (2).ipynb
# EX7_Clustering_KMeans_GMM_24BAD002 (1).ipynb
# EX_8_Apriori_and_PCA (1).ipynb
# EX7_Clustering_KMeans_GMM_24BAD002.ipynb
# EX_10_Recommendation_Systems_SVD_NMF (1).ipynb
# EX_10_Recommendation_Systems_SVD_NMF.ipynb
# EX_8_Apriori_and_PCA.ipynb
# scenario1_user_based_cf (3).ipynb
# Untitled5.ipynb
# Untitled6.ipynb
# Untitled7.ipynb
# Untitled8.ipynb
# Untitled9.ipynb
# Untitled10.ipynb
# Copy of Untitled10.ipynb
# Untitled11.ipynb
# Untitled
# ...

# %% [markdown]
# Once you've identified the correct file name from the output above, update the `NOTEBOOK_PATH` variable in the first code cell (`HZqtRpuv1C-V`).
#
# Also, remember to replace `GITHUB_USERNAME` and `GITHUB_TOKEN` with your actual GitHub credentials in cell `HZqtRpuv1C-V`.
