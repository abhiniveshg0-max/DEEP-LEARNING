# %% [markdown]
# <a href="https://colab.research.google.com/github/abhiniveshg0-max/DEEP-LEARNING/blob/main/experiment_4_b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras import layers, models

NUM_CLASSES = len(class_names)
IMG_SIZE = (224, 224)

base_model = ResNet50(
    weights='imagenet',
    include_top=False,
    input_shape=IMG_SIZE + (3,)
)

base_model.trainable = False

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128),
    layers.Activation('relu'),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES),
    layers.Activation('softmax')
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

print("\nTrainable layers:")
for layer in model.layers:
    print(layer.name, "-> trainable:", layer.trainable)
# Out:
# ...
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 128)            │             0 │
# ...

# %% [markdown]
# ### Define `class_names` and `IMG_SIZE`
#
# Before building the model, we need to define `class_names` (the labels for your classification task) and the `IMG_SIZE` for processing images. `class_names` are typically derived from the names of subfolders within your dataset directory, where each subfolder contains images for a specific class.

# %%
import os

# TODO: Update this path to your dataset's root directory
DATASET_PATH = '/path/to/your/dataset'

# Dynamically get class names from subdirectories
# Ensure that DATASET_PATH points to a directory containing subdirectories named after your classes
if os.path.exists(DATASET_PATH):
    class_names = sorted([d.name for d in os.scandir(DATASET_PATH) if d.is_dir()])
    print(f"Detected classes: {class_names}")
else:
    # Fallback or raise an error if the path is invalid
    print(f"Warning: Dataset path '{DATASET_PATH}' does not exist. Please update DATASET_PATH.")
    # You might want to define class_names manually here if the path doesn't exist yet
    class_names = ['class_a', 'class_b', 'class_c'] # Placeholder - UPDATE THIS MANUALLY IF PATH IS INVALID

NUM_CLASSES = len(class_names)
IMG_SIZE = (224, 224)

print(f"Number of classes: {NUM_CLASSES}")
print(f"Image size for model input: {IMG_SIZE}")
# Out:
# ...
# Number of classes: 3
# Image size for model input: (224, 224)
